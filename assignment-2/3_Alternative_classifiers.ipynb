# %% [markdown]
# # Assignment 2 - Part C: Trying alternative classifiers

# %% [markdown]
# This is a skeleton for trying alternative classifiers on the basketball dataset.

# %%
import csv
from pprint import pprint

# %% [markdown]
# We can define, as done in Practicum 6, a data loading in a way to obtain the attributes set and class labels for each the training and the test sets.

# %%
ATTRS = ["LOCATION", "W", "FINAL_MARGIN", "SHOT_NUMBER", "PERIOD", "GAME_CLOCK", "SHOT_CLOCK", "DRIBBLES", "TOUCH_TIME",
         "SHOT_DIST", "PTS_TYPE", "CLOSE_DEF_DIST", "SHOT_RESULT"]
ATTRS_WO_CLASS = 12

def load_data(filename):
    train_x = []
    train_y = []
    test_x = []
    test_y = []
    with open(filename, 'rt') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=',')
        i = 0
        for row in csvreader:
            if len(row) == ATTRS_WO_CLASS + 1:
                i += 1
                instance = [row[i] for i in range(ATTRS_WO_CLASS)]  # first ATTRS_WO_CLASS values are attributes
                label = row[ATTRS_WO_CLASS]  # (ATTRS_WO_CLASS + 1)th value is the class label
                if i % 3 == 0:  # test instance
                    test_x.append(instance)
                    test_y.append(label)
                else:  # train instance
                    train_x.append(instance)
                    train_y.append(label)
                    
    return train_x, train_y, test_x, test_y

# %% [markdown]
# And then we can use it to load the data.

# %%
train_x, train_y, test_x, test_y = load_data("basketball.train.csv")

# %% [markdown]
# Scikit-learn needs that all the attribute values to be numeric. This is, we need to binarize all the non-numeric attribute values, to obtain vectors: records having only numbers. The `DictVectorizer` class provided by scikit-learn allows to do this easily.

# %%
from sklearn.feature_extraction import DictVectorizer

# %% [markdown]
# Mind that each `train_x` and `test_x` are a list of lists.
#
# We just need to obtain from each a list of dictionaries (as done in previous practica where each record was a dictionary).

# %%
dicts_train_x = []
for x in train_x:
    d = {}
    for i, attr in enumerate(ATTRS):
        if i < len(ATTRS) - 1: # we removed class from train_x elems
            val = x[i]
            # save as floats the values for the already-numeric attributes from dataset, keep the rest as the strings they are
            if i not in [0, 1, 4, 10]:  # indices for "LOCATION", "W", "PERIOD", "PTS_TYPE" attributes
                val = float(val)
            d[attr] = val
    dicts_train_x.append(d)
# Out:
# [{'CLOSE_DEF_DIST': 1.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 13.0,
#   'GAME_CLOCK': 399.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.1,
#   'SHOT_DIST': 0.5,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 3.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 369.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.8,
#   'SHOT_DIST': 16.3,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 3.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 12.0,
#   'GAME_CLOCK': 436.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.1,
#   'SHOT_DIST': 20.2,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.0,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 253.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.0,
#   'SHOT_DIST': 8.1,
#   'SHOT_NUMBER': 16.0,
#   'TOUCH_TIME': 5.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 13.0,
#   'GAME_CLOCK': 47.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.0,
#   'SHOT_DIST': 24.2,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.8,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 696.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 21.7,
#   'SHOT_DIST': 1.2,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 2.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 1.0,
#   'GAME_CLOCK': 27.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.7,
#   'SHOT_DIST': 7.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.2,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 287.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 3.4,
#   'SHOT_DIST': 6.3,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 4.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 572.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.6,
#   'SHOT_DIST': 2.6,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 0.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 22.0,
#   'GAME_CLOCK': 406.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 17.1,
#   'SHOT_DIST': 25.9,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 470.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.6,
#   'SHOT_DIST': 21.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 23.0,
#   'GAME_CLOCK': 279.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.1,
#   'SHOT_DIST': 23.6,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 0.4,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 386.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 2.2,
#   'SHOT_DIST': 5.9,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 6.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 9.0,
#   'GAME_CLOCK': 685.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 26.3,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.0,
#   'DRIBBLES': 10.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 119.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.0,
#   'SHOT_DIST': 17.3,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 8.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 497.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 0.6,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 0.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 533.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.4,
#   'SHOT_DIST': 11.1,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 2.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -15.0,
#   'GAME_CLOCK': 489.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 11.5,
#   'SHOT_DIST': 23.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 328.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.9,
#   'SHOT_DIST': 16.9,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 28.0,
#   'GAME_CLOCK': 34.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 23.3,
#   'SHOT_DIST': 1.1,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.3,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -4.0,
#   'GAME_CLOCK': 327.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.0,
#   'SHOT_DIST': 1.6,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 6.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 0.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 422.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.2,
#   'SHOT_DIST': 3.1,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.1,
#   'DRIBBLES': 8.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 119.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 1.0,
#   'SHOT_DIST': 11.5,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 6.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -13.0,
#   'GAME_CLOCK': 403.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.4,
#   'SHOT_DIST': 5.0,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 5.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 15.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 13.0,
#   'GAME_CLOCK': 330.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 19.9,
#   'SHOT_DIST': 23.3,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 14.0,
#   'FINAL_MARGIN': 16.0,
#   'GAME_CLOCK': 245.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.8,
#   'SHOT_DIST': 6.9,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 11.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -16.0,
#   'GAME_CLOCK': 574.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.4,
#   'SHOT_DIST': 8.0,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -11.0,
#   'GAME_CLOCK': 227.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.0,
#   'SHOT_DIST': 3.2,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 522.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 5.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 318.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 11.0,
#   'SHOT_DIST': 22.4,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 12.0,
#   'GAME_CLOCK': 48.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.5,
#   'SHOT_DIST': 2.8,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 27.0,
#   'GAME_CLOCK': 575.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 17.3,
#   'SHOT_DIST': 23.1,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 14.0,
#   'GAME_CLOCK': 522.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.7,
#   'SHOT_DIST': 24.2,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -36.0,
#   'GAME_CLOCK': 138.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 2.1,
#   'SHOT_DIST': 21.9,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 1.5,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -27.0,
#   'GAME_CLOCK': 612.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.0,
#   'SHOT_DIST': 9.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': 26.0,
#   'GAME_CLOCK': 179.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.5,
#   'SHOT_DIST': 3.6,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 4.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 558.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 18.7,
#   'SHOT_DIST': 22.6,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 657.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.4,
#   'SHOT_DIST': 12.4,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 4.5,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -18.0,
#   'GAME_CLOCK': 661.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 12.2,
#   'SHOT_DIST': 22.8,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.7,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': 48.0,
#   'GAME_CLOCK': 313.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.3,
#   'SHOT_DIST': 21.0,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 5.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 383.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.0,
#   'SHOT_DIST': 8.6,
#   'SHOT_NUMBER': 17.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': 43.0,
#   'GAME_CLOCK': 46.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.5,
#   'SHOT_DIST': 6.3,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 3.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 431.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 18.0,
#   'SHOT_DIST': 9.7,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 5.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 8.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 445.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.2,
#   'SHOT_DIST': 19.1,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 144.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 18.4,
#   'SHOT_DIST': 22.9,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -26.0,
#   'GAME_CLOCK': 507.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.3,
#   'SHOT_DIST': 18.8,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 0.5,
#   'DRIBBLES': 7.0,
#   'FINAL_MARGIN': -19.0,
#   'GAME_CLOCK': 657.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 3.5,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 7.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 7.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 566.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.9,
#   'SHOT_DIST': 20.4,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 6.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 344.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.9,
#   'SHOT_DIST': 19.8,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 3.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.7,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -14.0,
#   'GAME_CLOCK': 53.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.0,
#   'SHOT_DIST': 19.3,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 2.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.7,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 537.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.5,
#   'SHOT_DIST': 20.9,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 4.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 161.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.7,
#   'SHOT_DIST': 15.9,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 5.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 28.0,
#   'GAME_CLOCK': 89.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.3,
#   'SHOT_DIST': 24.3,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 253.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.1,
#   'SHOT_DIST': 16.8,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.8,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 254.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.9,
#   'SHOT_DIST': 9.6,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 3.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -19.0,
#   'GAME_CLOCK': 512.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.4,
#   'SHOT_DIST': 25.5,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 571.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.9,
#   'SHOT_DIST': 8.4,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 2.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -31.0,
#   'GAME_CLOCK': 677.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.9,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 3.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 263.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.1,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 519.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 1.5,
#   'SHOT_DIST': 25.2,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.5,
#   'DRIBBLES': 11.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 448.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.4,
#   'SHOT_DIST': 18.9,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 6.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.1,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 682.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 16.1,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 2.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.1,
#   'DRIBBLES': 18.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 53.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.1,
#   'SHOT_DIST': 20.0,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 18.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.2,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -17.0,
#   'GAME_CLOCK': 257.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.3,
#   'SHOT_DIST': 5.0,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 3.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 704.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.9,
#   'SHOT_DIST': 3.1,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 3.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 70.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.5,
#   'SHOT_DIST': 6.3,
#   'SHOT_NUMBER': 21.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 1.0,
#   'GAME_CLOCK': 538.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 3.9,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 3.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 9.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 171.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 18.2,
#   'SHOT_DIST': 12.1,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 6.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 0.6,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 20.0,
#   'GAME_CLOCK': 557.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.2,
#   'SHOT_DIST': 2.5,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.5,
#   'DRIBBLES': 10.0,
#   'FINAL_MARGIN': -4.0,
#   'GAME_CLOCK': 110.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.8,
#   'SHOT_DIST': 13.7,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 8.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -19.0,
#   'GAME_CLOCK': 398.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 18.3,
#   'SHOT_DIST': 6.2,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 5.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 263.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.6,
#   'SHOT_DIST': 20.8,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 267.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.5,
#   'SHOT_DIST': 10.9,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 2.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 132.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 12.7,
#   'SHOT_DIST': 22.6,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.6,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 21.0,
#   'GAME_CLOCK': 204.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 2.2,
#   'SHOT_DIST': 7.7,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 5.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 223.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.4,
#   'SHOT_DIST': 5.1,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -15.0,
#   'GAME_CLOCK': 28.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.4,
#   'SHOT_DIST': 2.7,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.0,
#   'DRIBBLES': 11.0,
#   'FINAL_MARGIN': 14.0,
#   'GAME_CLOCK': 529.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 9.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 0.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 518.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 21.0,
#   'SHOT_DIST': 3.2,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -21.0,
#   'GAME_CLOCK': 661.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.4,
#   'SHOT_DIST': 6.7,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.0,
#   'DRIBBLES': 19.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 12.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.4,
#   'SHOT_DIST': 12.0,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 17.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.0,
#   'DRIBBLES': 10.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 37.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.3,
#   'SHOT_DIST': 16.0,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 9.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 32.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 15.2,
#   'SHOT_DIST': 24.2,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.2,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 625.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 2.8,
#   'SHOT_DIST': 19.5,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 651.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 10.5,
#   'SHOT_DIST': 22.4,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 280.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 14.2,
#   'SHOT_DIST': 25.0,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -22.0,
#   'GAME_CLOCK': 401.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.8,
#   'SHOT_DIST': 2.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 283.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.1,
#   'SHOT_DIST': 18.2,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.0,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 364.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.0,
#   'SHOT_DIST': 21.3,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 5.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 297.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.7,
#   'SHOT_DIST': 1.6,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -11.0,
#   'GAME_CLOCK': 201.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.9,
#   'SHOT_DIST': 18.1,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -13.0,
#   'GAME_CLOCK': 702.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 23.3,
#   'SHOT_DIST': 4.1,
#   'SHOT_NUMBER': 16.0,
#   'TOUCH_TIME': 1.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 351.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.3,
#   'SHOT_DIST': 1.1,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.3,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 13.0,
#   'GAME_CLOCK': 565.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.0,
#   'SHOT_DIST': 4.1,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 2.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 688.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 21.1,
#   'SHOT_DIST': 0.8,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 7.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 284.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.5,
#   'SHOT_DIST': 17.1,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 8.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.0,
#   'DRIBBLES': 11.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 272.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.1,
#   'SHOT_DIST': 3.4,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 11.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 312.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 16.8,
#   'SHOT_DIST': 24.7,
#   'SHOT_NUMBER': 12.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 1.0,
#   'GAME_CLOCK': 619.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 3.0,
#   'SHOT_DIST': 30.8,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.5,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': 1.0,
#   'GAME_CLOCK': 153.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.9,
#   'SHOT_DIST': 13.6,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 4.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.3,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -4.0,
#   'GAME_CLOCK': 18.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.7,
#   'SHOT_DIST': 4.7,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 2.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.5,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 53.0,
#   'GAME_CLOCK': 54.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.0,
#   'SHOT_DIST': 25.5,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 2.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 20.0,
#   'GAME_CLOCK': 75.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.6,
#   'SHOT_DIST': 3.9,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 569.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.7,
#   'SHOT_DIST': 12.1,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 612.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.9,
#   'SHOT_DIST': 19.3,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 10.0,
#   'GAME_CLOCK': 634.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.6,
#   'SHOT_DIST': 4.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 568.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.0,
#   'SHOT_DIST': 0.9,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 581.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.0,
#   'SHOT_DIST': 7.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 2.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -2.0,
#   'GAME_CLOCK': 505.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.5,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 701.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.1,
#   'SHOT_DIST': 19.3,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 4.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.8,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 618.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.0,
#   'SHOT_DIST': 16.1,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 2.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.3,
#   'DRIBBLES': 8.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 170.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.9,
#   'SHOT_DIST': 8.4,
#   'SHOT_NUMBER': 16.0,
#   'TOUCH_TIME': 8.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 382.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.2,
#   'SHOT_DIST': 1.2,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.0,
#   'DRIBBLES': 20.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 9.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 1.8,
#   'SHOT_DIST': 24.8,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 22.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -14.0,
#   'GAME_CLOCK': 482.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 1.6,
#   'SHOT_DIST': 26.1,
#   'SHOT_NUMBER': 15.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.2,
#   'DRIBBLES': 10.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 267.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.1,
#   'SHOT_DIST': 3.7,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 8.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 379.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 2.0,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 0.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -14.0,
#   'GAME_CLOCK': 44.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.0,
#   'SHOT_DIST': 10.2,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 2.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -3.0,
#   'GAME_CLOCK': 426.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 19.2,
#   'SHOT_DIST': 22.7,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.0,
#   'DRIBBLES': 11.0,
#   'FINAL_MARGIN': 9.0,
#   'GAME_CLOCK': 402.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.5,
#   'SHOT_DIST': 8.5,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 15.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 14.0,
#   'GAME_CLOCK': 652.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.5,
#   'SHOT_DIST': 19.3,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 10.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 4.3,
#   'SHOT_DIST': 25.1,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 513.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.0,
#   'SHOT_DIST': 24.0,
#   'SHOT_NUMBER': 12.0,
#   'TOUCH_TIME': 1.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 21.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 18.0,
#   'GAME_CLOCK': 475.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 21.0,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 37.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.3,
#   'SHOT_DIST': 2.8,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 2.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 182.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 13.8,
#   'SHOT_DIST': 24.4,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.5,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -16.0,
#   'GAME_CLOCK': 62.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.6,
#   'SHOT_DIST': 17.0,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 5.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.5,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -16.0,
#   'GAME_CLOCK': 78.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 2.7,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 3.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -2.0,
#   'GAME_CLOCK': 391.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 23.1,
#   'SHOT_DIST': 13.1,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 1.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 349.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 14.4,
#   'SHOT_DIST': 24.1,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.0,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -15.0,
#   'GAME_CLOCK': 639.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.7,
#   'SHOT_DIST': 4.9,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 3.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.3,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 367.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.3,
#   'SHOT_DIST': 22.0,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 3.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -18.0,
#   'GAME_CLOCK': 405.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 2.3,
#   'SHOT_DIST': 10.9,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.0,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -28.0,
#   'GAME_CLOCK': 216.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 13.3,
#   'SHOT_NUMBER': 15.0,
#   'TOUCH_TIME': 4.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 9.0,
#   'GAME_CLOCK': 637.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.9,
#   'SHOT_DIST': 2.8,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 263.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 21.5,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 4.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 276.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.0,
#   'SHOT_DIST': 3.4,
#   'SHOT_NUMBER': 19.0,
#   'TOUCH_TIME': 4.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 513.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.8,
#   'SHOT_DIST': 3.8,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 0.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 10.0,
#   'GAME_CLOCK': 470.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.5,
#   'SHOT_DIST': 4.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 401.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.0,
#   'SHOT_DIST': 3.6,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 6.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 9.0,
#   'GAME_CLOCK': 406.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.1,
#   'SHOT_DIST': 1.0,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.2,
#   'DRIBBLES': 13.0,
#   'FINAL_MARGIN': -13.0,
#   'GAME_CLOCK': 591.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.6,
#   'SHOT_DIST': 8.2,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 10.5,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.6,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 641.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.8,
#   'SHOT_DIST': 14.5,
#   'SHOT_NUMBER': 15.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -10.0,
#   'GAME_CLOCK': 382.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 21.9,
#   'SHOT_DIST': 23.6,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 1.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 605.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.0,
#   'SHOT_DIST': 18.4,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -11.0,
#   'GAME_CLOCK': 705.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 4.6,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 214.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.8,
#   'SHOT_DIST': 2.7,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -11.0,
#   'GAME_CLOCK': 113.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 0.0,
#   'SHOT_DIST': 14.3,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 10.0,
#   'GAME_CLOCK': 317.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.6,
#   'SHOT_DIST': 11.5,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 306.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.5,
#   'SHOT_DIST': 24.6,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 10.0,
#   'GAME_CLOCK': 317.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 17.9,
#   'SHOT_DIST': 2.2,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 15.0,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 655.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 21.6,
#   'SHOT_DIST': 2.8,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 1.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 557.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.1,
#   'SHOT_DIST': 23.3,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 167.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 5.8,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 18.0,
#   'GAME_CLOCK': 171.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 4.1,
#   'SHOT_DIST': 24.3,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -4.0,
#   'GAME_CLOCK': 61.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.0,
#   'SHOT_DIST': 2.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 16.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 237.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.3,
#   'SHOT_DIST': 9.9,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 13.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 683.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.6,
#   'SHOT_DIST': 11.7,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 4.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -2.0,
#   'GAME_CLOCK': 445.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 0.5,
#   'SHOT_DIST': 8.0,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 6.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': 10.0,
#   'GAME_CLOCK': 612.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 17.6,
#   'SHOT_DIST': 4.4,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 6.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 8.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 20.0,
#   'GAME_CLOCK': 134.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.9,
#   'SHOT_DIST': 25.1,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 0.0,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 313.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.2,
#   'SHOT_DIST': 3.2,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 5.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 468.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.0,
#   'SHOT_DIST': 1.5,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.4,
#   'DRIBBLES': 11.0,
#   'FINAL_MARGIN': 12.0,
#   'GAME_CLOCK': 306.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.6,
#   'SHOT_DIST': 8.1,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 10.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 382.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.0,
#   'SHOT_DIST': 25.9,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.6,
#   'DRIBBLES': 9.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 53.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 0.9,
#   'SHOT_DIST': 18.0,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 10.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -4.0,
#   'GAME_CLOCK': 447.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 18.5,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 363.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.4,
#   'SHOT_DIST': 9.2,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 1.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 389.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.5,
#   'SHOT_DIST': 8.1,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 5.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.6,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 292.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.4,
#   'SHOT_DIST': 20.0,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 2.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -17.0,
#   'GAME_CLOCK': 371.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 18.9,
#   'SHOT_DIST': 3.1,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 3.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 12.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 42.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 14.0,
#   'SHOT_DIST': 25.4,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.9,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -10.0,
#   'GAME_CLOCK': 659.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.4,
#   'SHOT_DIST': 18.1,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 4.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 0.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 440.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.9,
#   'SHOT_DIST': 3.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 190.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.6,
#   'SHOT_DIST': 1.3,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 5.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 488.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 1.8,
#   'SHOT_DIST': 1.4,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 9.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 62.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.7,
#   'SHOT_DIST': 4.3,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 8.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.5,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 38.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.5,
#   'SHOT_DIST': 6.0,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 4.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.0,
#   'DRIBBLES': 13.0,
#   'FINAL_MARGIN': 14.0,
#   'GAME_CLOCK': 428.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.0,
#   'SHOT_DIST': 20.9,
#   'SHOT_NUMBER': 16.0,
#   'TOUCH_TIME': 13.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.1,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 25.0,
#   'GAME_CLOCK': 685.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.7,
#   'SHOT_DIST': 5.4,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 5.1,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': -3.0,
#   'GAME_CLOCK': 576.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.9,
#   'SHOT_DIST': 8.7,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 4.2,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -20.0,
#   'GAME_CLOCK': 326.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.3,
#   'SHOT_DIST': 16.0,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 3.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.7,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 16.0,
#   'GAME_CLOCK': 370.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.0,
#   'SHOT_DIST': 13.6,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 6.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.8,
#   'DRIBBLES': 8.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 78.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 16.6,
#   'SHOT_DIST': 24.0,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 7.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.6,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 251.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.2,
#   'SHOT_DIST': 7.0,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 2.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 4.0,
#   'GAME_CLOCK': 33.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 1.0,
#   'SHOT_DIST': 11.4,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 3.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 612.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 6.7,
#   'SHOT_DIST': 22.7,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 9.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -14.0,
#   'GAME_CLOCK': 445.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 22.3,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -24.0,
#   'GAME_CLOCK': 628.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.4,
#   'SHOT_DIST': 15.6,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 5.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 0.7,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -10.0,
#   'GAME_CLOCK': 226.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.5,
#   'SHOT_DIST': 7.0,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 5.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 14.0,
#   'GAME_CLOCK': 248.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.4,
#   'SHOT_DIST': 3.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 3.7,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -21.0,
#   'GAME_CLOCK': 8.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.5,
#   'SHOT_DIST': 19.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 4.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 15.0,
#   'GAME_CLOCK': 28.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 3.7,
#   'SHOT_DIST': 22.3,
#   'SHOT_NUMBER': 19.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 12.0,
#   'GAME_CLOCK': 256.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.9,
#   'SHOT_DIST': 2.7,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 42.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 15.8,
#   'SHOT_DIST': 26.5,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 538.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.8,
#   'SHOT_DIST': 16.4,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 647.0,
#   'LOCATION': 'A',
# ...
#  {'CLOSE_DEF_DIST': 3.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -25.0,
#   'GAME_CLOCK': 571.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 4.4,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 502.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 13.3,
#   'SHOT_DIST': 13.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': 25.0,
#   'GAME_CLOCK': 203.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 3.5,
#   'SHOT_DIST': 17.3,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 4.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 507.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 17.9,
#   'SHOT_DIST': 23.8,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 0.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 33.0,
#   'GAME_CLOCK': 126.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.8,
#   'SHOT_DIST': 7.9,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 6.3,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.6,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 5.0,
#   'GAME_CLOCK': 386.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 11.3,
#   'SHOT_DIST': 12.9,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 1.0,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.7,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -40.0,
#   'GAME_CLOCK': 376.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 8.4,
#   'SHOT_DIST': 10.8,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.1,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 215.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 15.2,
#   'SHOT_DIST': 18.5,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 243.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.7,
#   'SHOT_DIST': 19.0,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.1,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 642.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.7,
#   'SHOT_DIST': 24.1,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 5.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 352.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 4.8,
#   'SHOT_DIST': 3.7,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 2.4,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 23.0,
#   'GAME_CLOCK': 136.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.4,
#   'SHOT_DIST': 4.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 9.5,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 18.0,
#   'GAME_CLOCK': 366.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 20.2,
#   'SHOT_DIST': 24.3,
#   'SHOT_NUMBER': 16.0,
#   'TOUCH_TIME': 2.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 271.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.0,
#   'SHOT_DIST': 14.4,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 2.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 8.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 431.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.5,
#   'SHOT_DIST': 14.0,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 4.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 117.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 6.1,
#   'SHOT_NUMBER': 7.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 8.0,
#   'GAME_CLOCK': 548.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.5,
#   'SHOT_DIST': 1.2,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -14.0,
#   'GAME_CLOCK': 517.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 12.7,
#   'SHOT_DIST': 25.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 17.0,
#   'GAME_CLOCK': 581.0,
#   'LOCATION': 'H',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 13.7,
#   'SHOT_DIST': 22.7,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 82.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.7,
#   'SHOT_DIST': 8.6,
#   'SHOT_NUMBER': 18.0,
#   'TOUCH_TIME': 4.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 27.0,
#   'GAME_CLOCK': 586.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.6,
#   'SHOT_DIST': 8.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 659.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 22.5,
#   'SHOT_DIST': 7.7,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.8,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 1.8,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 172.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.6,
#   'SHOT_DIST': 5.3,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.1,
#   'DRIBBLES': 2.0,
#   'FINAL_MARGIN': -1.0,
#   'GAME_CLOCK': 703.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 9.3,
#   'SHOT_DIST': 9.7,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.8,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -7.0,
#   'GAME_CLOCK': 706.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 10.1,
#   'SHOT_DIST': 23.0,
#   'SHOT_NUMBER': 11.0,
#   'TOUCH_TIME': 1.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 573.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 24.0,
#   'SHOT_DIST': 5.6,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -12.0,
#   'GAME_CLOCK': 270.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 7.7,
#   'SHOT_DIST': 24.3,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.7,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 7.0,
#   'GAME_CLOCK': 403.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.6,
#   'SHOT_DIST': 1.5,
#   'SHOT_NUMBER': 6.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 4.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 499.0,
#   'LOCATION': 'A',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 3.1,
#   'SHOT_DIST': 26.1,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 6.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -15.0,
#   'GAME_CLOCK': 309.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 19.0,
#   'SHOT_DIST': 22.8,
#   'SHOT_NUMBER': 10.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.9,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 239.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 18.0,
#   'SHOT_DIST': 2.9,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 2.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 587.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 16.0,
#   'SHOT_DIST': 24.5,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 7.6,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 310.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 19.7,
#   'SHOT_DIST': 24.6,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 1.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.0,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 102.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.1,
#   'SHOT_DIST': 9.0,
#   'SHOT_NUMBER': 9.0,
#   'TOUCH_TIME': 0.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -6.0,
#   'GAME_CLOCK': 246.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.0,
#   'SHOT_DIST': 14.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 5.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 16.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 11.0,
#   'GAME_CLOCK': 92.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 8.2,
#   'SHOT_DIST': 23.0,
#   'SHOT_NUMBER': 4.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.6,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 289.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 20.0,
#   'SHOT_DIST': 18.7,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.9,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.4,
#   'DRIBBLES': 1.0,
#   'FINAL_MARGIN': -9.0,
#   'GAME_CLOCK': 462.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.5,
#   'SHOT_DIST': 13.7,
#   'SHOT_NUMBER': 13.0,
#   'TOUCH_TIME': 1.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.9,
#   'DRIBBLES': 6.0,
#   'FINAL_MARGIN': -27.0,
#   'GAME_CLOCK': 589.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 19.7,
#   'SHOT_DIST': 16.9,
#   'SHOT_NUMBER': 8.0,
#   'TOUCH_TIME': 5.0,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -2.0,
#   'GAME_CLOCK': 600.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.9,
#   'SHOT_DIST': 15.8,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 5.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -10.0,
#   'GAME_CLOCK': 94.0,
#   'LOCATION': 'H',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 6.4,
#   'SHOT_DIST': 19.9,
#   'SHOT_NUMBER': 18.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 3.5,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 15.0,
#   'GAME_CLOCK': 113.0,
#   'LOCATION': 'H',
#   'PERIOD': '3',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 14.0,
#   'SHOT_DIST': 25.1,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 1.2,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 5.4,
#   'DRIBBLES': 5.0,
#   'FINAL_MARGIN': -8.0,
#   'GAME_CLOCK': 698.0,
#   'LOCATION': 'H',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 5.6,
#   'SHOT_DIST': 22.4,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 6.4,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.7,
#   'DRIBBLES': 9.0,
#   'FINAL_MARGIN': 6.0,
#   'GAME_CLOCK': 346.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.4,
#   'SHOT_DIST': 23.4,
#   'SHOT_NUMBER': 2.0,
#   'TOUCH_TIME': 8.5,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 6.3,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': 2.0,
#   'GAME_CLOCK': 338.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '3',
#   'SHOT_CLOCK': 9.7,
#   'SHOT_DIST': 24.2,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.6,
#   'W': 'W'},
#  {'CLOSE_DEF_DIST': 2.9,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -23.0,
#   'GAME_CLOCK': 626.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 14.2,
#   'SHOT_DIST': 20.0,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 0.8,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 2.8,
#   'DRIBBLES': 3.0,
#   'FINAL_MARGIN': -22.0,
#   'GAME_CLOCK': 318.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 10.8,
#   'SHOT_DIST': 3.8,
#   'SHOT_NUMBER': 14.0,
#   'TOUCH_TIME': 4.3,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.2,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -18.0,
#   'GAME_CLOCK': 190.0,
#   'LOCATION': 'A',
#   'PERIOD': '2',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 12.1,
#   'SHOT_DIST': 6.6,
#   'SHOT_NUMBER': 3.0,
#   'TOUCH_TIME': 0.9,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 1.7,
#   'DRIBBLES': 4.0,
#   'FINAL_MARGIN': -3.0,
#   'GAME_CLOCK': 215.0,
#   'LOCATION': 'A',
#   'PERIOD': '4',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 16.5,
#   'SHOT_DIST': 7.1,
#   'SHOT_NUMBER': 5.0,
#   'TOUCH_TIME': 6.7,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 7.1,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -5.0,
#   'GAME_CLOCK': 341.0,
#   'LOCATION': 'A',
#   'PERIOD': '1',
#   'PTS_TYPE': '2',
#   'SHOT_CLOCK': 7.8,
#   'SHOT_DIST': 19.7,
#   'SHOT_NUMBER': 1.0,
#   'TOUCH_TIME': 1.1,
#   'W': 'L'},
#  {'CLOSE_DEF_DIST': 4.4,
#   'DRIBBLES': 0.0,
#   'FINAL_MARGIN': -11.0,
#   'GAME_CLOCK':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e172c36fdf7f> in <module>()
#      10             d[attr] = val
#      11     dicts_train_x.append(d)
# ---> 12 pprint(dicts_train_x)
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in pprint(object, stream, indent, width, depth, compact)
#      51         stream=stream, indent=indent, width=width, depth=depth,
#      52         compact=compact)
# ---> 53     printer.pprint(object)
#      54
#      55 def pformat(object, indent=1, width=80, depth=None, *, compact=False):
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in pprint(self, object)
#     137
#     138     def pprint(self, object):
# --> 139         self._format(object, self._stream, 0, 0, {}, 0)
#     140         self._stream.write("\n")
#     141
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     208         stream.write('[')
#     209         self._format_items(object, stream, indent, allowance + 1,
# --> 210                            context, level)
#     211         stream.write(']')
#     212
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     387             self._format(ent, stream, indent,
#     388                          allowance if last else 1,
# --> 389                          context, level)
#     390
#     391     def _repr(self, object, context, level):
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174                 del context[objid]
#     175                 return
# --> 176         stream.write(rep)
#     177
#     178     _dispatch = {}
#
# /Users/dario/anaconda3/anaconda/lib/python3.5/site-packages/ipykernel/iostream.py in write(self, string)
#     315
#     316             is_child = (not self._is_master_process())
# --> 317             self._buffer.write(string)
#     318             if is_child:
#     319                 # newlines imply flush in subprocesses
#
# ValueError: I/O operation on closed file

# %% [markdown]
# Finally, the `fit_transform` method of the vectorizer binarizes the non-numeric attributes in the list of dictionaries, and returns the vector we need.

# %%
vectorizer_train = DictVectorizer()
vec_train_x = vectorizer_train.fit_transform(dicts_train_x).toarray()
print(vec_train_x)
# Out:
# [[  1.    0.   13.  ...,   3.7   0.    1. ]
#  [  5.9   0.  -12.  ...,   3.2   1.    0. ]
#  [  5.    0.   12.  ...,   1.1   0.    1. ]
#  ...,
#  [  3.8   1.   -7.  ...,   0.6   1.    0. ]
#  [  8.6   0.    8.  ...,   0.    0.    1. ]
#  [  7.2   0.   -9.  ...,   1.    1.    0. ]]

# %% [markdown]
# We do similarly for vectorizing `test_x`.

# %%
dicts_test_x = []
# TODO

vectorizer_test = DictVectorizer()
vec_test_x = # TODO

# %% [markdown]
# Having `evaluate` defined somewhere, we are ready to learn and apply the model, similarly to Task 3 of Practicum 6. But here, we use the vectors recently obtained for the input sets. E.g., for Naive Bayes classifier:

# %%
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(vec_train_x, train_y)
predictions = clf.predict(vec_test_x)
evaluate(predictions, test_y)
